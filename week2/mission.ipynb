# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Score():
    def __init__(self,mid,final): # '__'로 변수를 private하게
        self.__mid = mid
        self.__final = final
    #외부에서 클래스 내부 변수를 참조하기 위해 > getter & setter 필요 : @property
    # getter를 통해 데이터를 받아옴
    @property
    def mid(self):
        return self.__mid
    # getter만 선언 > 읽기 전용 변수
    @property
    def final(self):
        return self.__final
    

score = Score(50,75)#mid, final
print((score.mid + score.final) / 2)
# Out:
# 62.5

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Car():
    def __init__(self, fuel, wheels):
        self.fuel = fuel
        self.wheels = wheels
        
class Bike(Car):
    def __init__(self, fuel : str, wheels : int, size : str):
        super().__init__(fuel, wheels) # 부모 객체 사용
        self.size = size # size 속성 추가
    

bike = Bike("gas", 2, "small")
print(bike.fuel, bike.wheels, bike.size)
# Out:
# gas 2 small

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import csv

# %%
file_path = "./data-01-test-score.csv"

# %%
class ReadCSV():
    def __init__(self,file_path):
        self.file_path = file_path
        
    def read_file(self):
        f = open(self.file_path, 'r')
        csv_data = list(csv.reader(f))
        return csv_data
        
        
read_csv = ReadCSV(file_path)
print(read_csv.read_file())
# Out:
# [['73', '80', '75', '152'], ['93', '88', '93', '185'], ['89', '91', '90', '180'], ['96', '98', '100', '196'], ['73', '66', '70', '142'], ['53', '46', '55', '101'], ['69', '74', '77', '149'], ['47', '56', '60', '115'], ['87', '79', '90', '175'], ['79', '70', '88', '164'], ['69', '70', '73', '141'], ['70', '65', '74', '141'], ['93', '95', '91', '184'], ['79', '80', '73', '152'], ['70', '73', '78', '148'], ['93', '89', '96', '192'], ['78', '75', '68', '147'], ['81', '90', '93', '183'], ['88', '92', '86', '177'], ['78', '83', '77', '159'], ['82', '86', '90', '177'], ['86', '82', '89', '175'], ['78', '83', '85', '175'], ['76', '83', '71', '149'], ['96', '93', '95', '192']]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class ReadCSV():
    def __init__(self,file_path):
        self.file_path = file_path
        
    def read_file(self):
        f = open(self.file_path, 'r')
        csv_data = list(csv.reader(f))

        for i, line in enumerate(csv_data):  
            # list_comprehension : str > int e.g. ['73', '80', '75', '152'] > [73, 80, 75, 152]
            line = [int(k) for k in line] 
            csv_data[i] = line # int형 리스트로 업데이트
        return csv_data
        
    def merge_list(self):
        result = []
        csv_data = self.read_file()
        
        for i in csv_data: # [73, 80, 75, 152]
            result.append(sum(i))
        return result

        
read_csv = ReadCSV(file_path)
print(read_csv.read_file())
print(read_csv.merge_list())
# Out:
# [[73, 80, 75, 152], [93, 88, 93, 185], [89, 91, 90, 180], [96, 98, 100, 196], [73, 66, 70, 142], [53, 46, 55, 101], [69, 74, 77, 149], [47, 56, 60, 115], [87, 79, 90, 175], [79, 70, 88, 164], [69, 70, 73, 141], [70, 65, 74, 141], [93, 95, 91, 184], [79, 80, 73, 152], [70, 73, 78, 148], [93, 89, 96, 192], [78, 75, 68, 147], [81, 90, 93, 183], [88, 92, 86, 177], [78, 83, 77, 159], [82, 86, 90, 177], [86, 82, 89, 175], [78, 83, 85, 175], [76, 83, 71, 149], [96, 93, 95, 192]]
# [380, 459, 450, 490, 351, 255, 369, 278, 431, 401, 353, 350, 463, 384, 369, 470, 368, 447, 443, 397, 435, 432, 421, 379, 476]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class ReadCSV():
    def __init__(self,file_path):
        self.file_path = file_path
        
    def read_file(self):
        f = open(self.file_path, 'r')
        csv_data = list(csv.reader(f))

        for i, line in enumerate(csv_data):  
            line = [int(k) for k in line] # list_comprehension
            csv_data[i] = line
        return csv_data
        
    def merge_list(self):
        result = []
        csv_data = self.read_file()
        
        for i in csv_data: # [73, 80, 75, 152]
            
            mean = sum(i)/len(i)
            result.append(mean)
            result.sort() #오름차순
        return result

        
read_csv = ReadCSV(file_path)

print(read_csv.merge_list())
# Out:
# [63.75, 69.5, 87.5, 87.75, 88.25, 92.0, 92.25, 92.25, 94.75, 95.0, 96.0, 99.25, 100.25, 105.25, 107.75, 108.0, 108.75, 110.75, 111.75, 112.5, 114.75, 115.75, 117.5, 119.0, 122.5]

# %% [markdown]
# # 최종 제출

# %%
# ------------- 1번 ---------------
class Score():
    def __init__(self,mid,final): # '__'로 변수를 private하게
        self.__mid = mid
        self.__final = final
    #외부에서 클래스 내부 변수를 참조하기 위해 > getter & setter 필요 : @property
    # getter를 통해 데이터를 받아옴
    @property
    def mid(self):
        return self.__mid
    # getter만 선언 > 읽기 전용 변수
    @property
    def final(self):
        return self.__final
    

score = Score(50,75)#mid, final
print((score.mid + score.final) / 2)

# ------------- 2번 ---------------
class Car():
    def __init__(self, fuel, wheels):
        self.fuel = fuel
        self.wheels = wheels
        
class Bike(Car):
    def __init__(self, fuel : str, wheels : int, size : str):
        super().__init__(fuel, wheels) # 부모 객체 사용
        self.size = size # size 속성 추가
    

bike = Bike("gas", 2, "small")
print(bike.fuel, bike.wheels, bike.size)

# ------------- 3번 ---------------
import csv

file_path = "./data-01-test-score.csv"


class ReadCSV():
    def __init__(self,file_path):
        self.file_path = file_path
        
    def read_file(self):
        f = open(self.file_path, 'r')
        csv_data = list(csv.reader(f))
        return csv_data
        
        
read_csv = ReadCSV(file_path)
print(read_csv.read_file())

# ------------- 4번 ---------------
class ReadCSV():
    def __init__(self,file_path):
        self.file_path = file_path
        
    def read_file(self):
        f = open(self.file_path, 'r')
        csv_data = list(csv.reader(f))

        for i, line in enumerate(csv_data):  
            # list_comprehension : str > int e.g. ['73', '80', '75', '152'] > [73, 80, 75, 152]
            line = [int(k) for k in line] 
            csv_data[i] = line # int형 리스트로 업데이트
        return csv_data
        
    def merge_list(self):
        result = []
        csv_data = self.read_file()
        
        for i in csv_data: # [73, 80, 75, 152]
            result.append(sum(i))
        return result

        
read_csv = ReadCSV(file_path)
print(read_csv.read_file())
print(read_csv.merge_list())

# ------------- 5번 ---------------
class ReadCSV():
    def __init__(self,file_path):
        self.file_path = file_path
        
    def read_file(self):
        f = open(self.file_path, 'r')
        csv_data = list(csv.reader(f))

        for i, line in enumerate(csv_data):  
            # list_comprehension : str > int e.g. ['73', '80', '75', '152'] > [73, 80, 75, 152]
            line = [int(k) for k in line] 
            csv_data[i] = line
        return csv_data
        
    def merge_list(self):
        result = []
        csv_data = self.read_file()
        
        for i in csv_data: # [73, 80, 75, 152]
            
            mean = sum(i)/len(i)
            result.append(mean)
            result.sort() #오름차순
        return result

        
read_csv = ReadCSV(file_path)

print(read_csv.merge_list())
# Out:
# 62.5
# gas 2 small
# [['73', '80', '75', '152'], ['93', '88', '93', '185'], ['89', '91', '90', '180'], ['96', '98', '100', '196'], ['73', '66', '70', '142'], ['53', '46', '55', '101'], ['69', '74', '77', '149'], ['47', '56', '60', '115'], ['87', '79', '90', '175'], ['79', '70', '88', '164'], ['69', '70', '73', '141'], ['70', '65', '74', '141'], ['93', '95', '91', '184'], ['79', '80', '73', '152'], ['70', '73', '78', '148'], ['93', '89', '96', '192'], ['78', '75', '68', '147'], ['81', '90', '93', '183'], ['88', '92', '86', '177'], ['78', '83', '77', '159'], ['82', '86', '90', '177'], ['86', '82', '89', '175'], ['78', '83', '85', '175'], ['76', '83', '71', '149'], ['96', '93', '95', '192']]
# ...

# %% [markdown]
# -----

# %% [markdown]
# # 2주차 라이브 강의

# %% [markdown]
# ## 학습 내용 정리

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# TF나 파이토치같은 프래임워크 하나를 집중해서 공부해보는 걸 추천
#     - NLP 관심 > NLTK, HUGGINGFACE 공부 추천

# %% [markdown]
# - OOP의 주요 특징 (상속,다형성, 가시성)
# - 1급 객체/함수(기억하자)
# - closures, decorator
# - 모듈과 패키지
# - 라이브러리
# - conda cheat sheet 읽어보기, 추천 명령어
# ![image.png](attachment:image.png)
#
# - 예외처리: exception(try~except)
# - file handling : with구문-.close()안해도 알아서 닫아주지만 다른 경우에서는 메모리 관리를 위해 close해주기
# - log handling
# - configparser :file parsing, value:str
# - argparse
#
# -data handling : csv(pandas와 함께 자주 사용), regex, xml,json
# ![image-2.png](attachment:image-2.png)
# - 데이터셋
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## 우수 미션 풀이
#
# ### 1번
# - @property : 외부에서 프라이빗 변수에 접근(get)
#
# ### 2번
# - 상속 : super()로 상위 클래스 변수 이용
#
# ### 3번
# - 파일입출력 readline()/readlines()
# - lambda 평균 계산
#
# ### 4번
# - 데이터 읽고 > int 변환 > 합 구하기
# ![image.png](attachment:image.png)
#
# ### 5번
# - sum > mean 구하기
# - list comprehension / lambda
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# -----

# %% [markdown]
# ## Q&A

# %% [markdown]
# - 어떤 마음가짐 ? 소프트 스킬이 잘 갖춰진 사람,자기가 모르는 부분을 해결하려고 노력하는 모습
# - 데코레이터? 요구조건이 다양한 경우, 함수 내에서 기능들을 다 구현할 수 있지만 그러기 보다는 데코레이터를 사용해서 배이스함수에다가 각각의 요구사항에 따른 걸 구현하도록
# - know where(내가 모르는 게,필요하는 게 어디에 있는지 잘 아는 거, 잘 찾을 수 있는 것)도 중요
# - 문제 풀이 사이트의 자료구조/알고리즘 문제를 이용해서 연습
# - 리트코드, 프로그래머스, 백준
# ![image.png](attachment:image.png)
# - 좋은 프로그래밍 습관 > 클린코드 찾아서 읽어보기
# - 초보를 위한 기술서적 : soft skill(개발자에게 필요한 소프트스킬, 학습법
# - 공부법 책 : 실용주의  사고 학습
# - 프로그래머들 간에 소통이 중요하기 때문에 엄청 난 성능 우선이 필요하지 않는 이상 직관성을 우선
# - 파이토치 vs. tf ,둘 다 유명하지만 파이토치가 좀 더 대중적이지 않을까
# - 작업할 때 로컬보단 리눅스에?
# - OS 라이센스 : MIT GPL, Apache,...상업용 가능한지 체크, 기업에선 라이센스는 따로 담당자가 있을것
# - vision tansformer: vision분야도 NLP처럼 앞으로도 수많은 파생모델이 나올 수 있지 않을까, 포텐셜이 큰 분야일듯. tansformer모델 기반으로 다양한 NLP 파생모델이 나와있음
# - mmdetection,detectron2도 현업에서 많이 쓰임
# - 예외처리, 일단 프로그램이 죽으면 안되니까 최대한 예외처리가 안나오게 개발해야 하고 나올 거 같으면 무조건 막기
